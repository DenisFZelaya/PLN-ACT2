# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# <h1> Dataset Boston Housing </h1>

# %% [markdown]
# El dataset de *Boston Housing* está compuesto de 506 registros del censo de 1970.
#
# Las variables que definen el problema son:
#
# <dl>
#   <dt><b>Crime Rate</b> (<i>crim</i>)</dt>
#     <dd>Crimen per cápita por ciudad</dd>
#   <dt><b>Residential Land Zones</b> (<i>zn</i>)</dt>
#     <dd>Proporción de terrenos residenciales divididos en zonas para lotes de más de 25,000 pies cuadrados (aproximadamente 2322.576 m<sup>2</sup>)</dd>
#   <dt><b>Non-retail Business Acres</b> (<i>indus</i>)</dt>
#     <dd>Proporción de acres (0.40 ha) de negocios no minoristas por ciudad</dd>
#   <dt><b>Charles River tract bounds</b> (<i>chas</i>)</dt>
#     <dd>Variable ficticia de Charles River (= 1 si colinda con el río, 0 de lo contrario)</dd>
#   <dt><b>N.O. Concentration</b> (<i>nox</i>)</dt>
#     <dd>Concentración de óxidos nítricos (partes por 10 millones)</dd>
#   <dt><b>No. of Rooms</b> (<i>rm</i>)</dt>
#     <dd>Número promedio de habitaciones por vivienda</dd>
#   <dt><b>Age</b> (<i>age</i>)</dt>
#     <dd>Proporción de unidades ocupadas por sus propietarios construidas antes de 1940</dd>
#   <dt><b>Distance to Employment</b> (<i>dis</i>)</dt>
#     <dd>Distancias desproporcionadas a cinco centros de empleo de Boston</dd>
#   <dt><b>Highway Accessibility</b> (<i>rad</i>)
#     <dd>Índice de accesibilidad a las autopistas</dd>
#   <dt><b>Property Tax Rate</b> (<i>tax</i>)
#     <dd>Tasa de impuesto a la propiedad de valor completo por USD 10,000</dd>
#   <dt><b>Pupil Teacher Ratio</b> (<i>ptratio</i>)</dt>
#     <dd>Colegios por localidad</dd>
#   <dt><b>B</b>
#     <dd>Proporción de negros por ciudad</dd>
#   <dt><b>% Lower Income</b> (<i>lstat</i>)
#     <dd>Porcentaje de estado inferior de la población</dd>
#   <dt><b>price</b><dt>
#     <dd>Valor mediano de las viviendas ocupadas por sus propietarios en USD 1000</dd>
# </dl>

# %% [markdown]
# <h2> Cargando el dataset Boston housing </h2>

# %%
# Se importa el dataset Boston housing
boston_housing = tf.keras.datasets.boston_housing

# Se cargan los conjuntos de entrenamiento (*_train_whole) y de validación (*_test) en variables separadas
(X_train_whole, y_train_whole), (X_test, y_test) = boston_housing.load_data()

# %%
# Impresión del número de muestras para el conjunto de entrenamiento y de validación

print(f'Número de muestras del conjunto de entrenamiento {X_train_whole.shape}')
print(f'Número de muestras del conjunto de prueba {X_test.shape}')
# Out:
# Número de muestras del conjunto de entrenamiento (404, 13)
# Número de muestras del conjunto de prueba (102, 13)

# %% [markdown]
# ### Se colocan los datos en un dataframe

# %%
import pandas as pd
import numpy as np

# Nombres de las variables
# Nombre largo
variables_boston_housing = ['Crime Rate', 'Residential Land Zones', 'Non-retail Business Acres', 'Charles River tract bounds', 'N.O. Concentration',
                '# of Rooms', 'Age', 'Distance to Employment', 'Highway Accessibility', 'Property Tax Rate', 'Pupil Teacher Ratio', 'B', '% Lower Income',
                'Housing value']
# Nombre corto
short_variables = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'B', 'lstat', 'price']

# Se inserta la variable independiente (y_train_whole) al final del las variables del problema
train_whole = np.insert(X_train_whole, -1, y_train_whole, axis=1)

# Se genera un dataframe con la información del conjunto de entrenamiento
df_train = pd.DataFrame(train_whole, columns = short_variables)

# %%
df_train.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis   rad    tax  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
#
#    ptratio       B  lstat  price
# 0     21.0  396.90   15.2  18.72
# 1     14.7  395.38   42.3   3.11
# 2     20.2  375.52   50.0   3.26
# 3     20.2  396.90   21.1   8.01
# 4     20.2  391.43   17.7  14.65

# %% [markdown]
# #### Valores nulos
#
# En caso de existir valores nulos, las soluciones más comunes son:
# 1. Eliminar las muestras (filas) o características (columnas) que contengan valores nulos.
# 2. Reemplazar por un valor constante, tal como la media, mediana, moda, etc.

# %%
df_train.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ee96d3489828> in <module>
# ----> 1 df_train.info()
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2555                 if "object" in counts or self.index._is_memory_usage_qualified():
#    2556                     size_qualifier = "+"
# -> 2557             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2558             lines.append(
#    2559                 "memory usage: {mem}\n".format(
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2653         )
#    2654         if index:
# -> 2655             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2656                 result
#    2657             )
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
df_train.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# B          0
# lstat      0
# price      0
# dtype: int64

# %% [markdown]
# <h3>Análisis de los datos</h3>

# %%
# Se calcula la información estadística, tal como media, desviación estándar, percentil, etc, de cada una de las columnas del dataframe
df_train.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-8bf120b3f3f4> in <module>
#       1 # Se calcula la información estadística, tal como media, desviación estándar, percentil, etc, de cada una de las columnas del dataframe
# ----> 2 df_train.describe()
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#   10263         elif (include is None) and (exclude is None):
#   10264             # when some numerics are found, keep only numerics
# > 10265             data = self.select_dtypes(include=[np.number])
#   10266             if len(data.columns) == 0:
#   10267                 data = self
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# -> 3427         include_these = Series(not bool(include), index=self.columns)
#    3428         exclude_these = Series(not bool(exclude), index=self.columns)
#    3429
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# ### Visualización

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Se grafican los diagramas de caja de cada una de las columnas del dataframe
boxplot = df_train[short_variables[:-1]].boxplot(figsize=(15,7))

plt.show()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
#
sb.histplot(np.concatenate((y_train_whole, y_test), axis=0), kde=True)
plt.show()

# %%
#
sb.boxplot(df_train["price"], orient='h')
plt.show()

# %% [markdown]
# ### Correlación entre las variables

# %%
correlation = df_train.corr()
print(correlation.loc['price'])

# Se calcula la matriz de correlación por pares de columnas, excluyendo los valores nulos
fig = plt.figure(figsize=(10, 10))

matriz_corr = df_train.corr()
# Mapa de calor de la matriz de correlación
ax = sb.heatmap(matriz_corr, linewidths=1.5, linecolor='white',
                cmap='coolwarm', annot=True)
plt.show()
# Out:
# crim       0.434384
# zn        -0.415237
# indus      0.603129
# chas      -0.011017
# nox        0.592994
# rm        -0.610844
# age        0.590898
# dis       -0.507075
# rad        0.490250
# tax        0.534752
# ptratio    0.365873
# B         -0.376081
# lstat     -0.730793
# price      1.000000
# Name: price, dtype: float64

# %%
# Revisamos los aChecking the scatter plot with the most correlated features
plt.figure(figsize = (20,5))
features = ['lstat','rm','ptratio']
for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = df_train[col]
    y = df_train.price
    print(i)
    print(col)
    plt.scatter(x, y, marker='o')
    plt.title("Variación de los precios de las casas")
    plt.xlabel(col)
    plt.ylabel("Precios de las casas en USD$1000")
plt.show()
# Out:
# 0
# lstat
# 1
# rm
# 2
# ptratio

# %% [markdown]
# ## Dividir el dataset

# %%
from sklearn.model_selection import train_test_split

# Se divide el dataset en 3 partes:
# 1. Train (entrenamiento)
# 2. Validation (validacion)
# 3. Test (prueba)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_whole, y_train_whole, test_size = 0.2, random_state = 4)

# %% [markdown]
# ## Normalización de datos

# %%
import numpy as np
from sklearn.preprocessing import normalize

Xtrain_norm = normalize(X_train_whole, axis=0)
Xvalid_norm = normalize(X_valid, axis=0)
X_test_norm = normalize(X_test, axis=0)

# %%
X_test_norm.shape
# Out:
# (102, 13)

# %% [markdown]
# ## Entrenamiento de la red neuronal multicapa

# %% [markdown]
# ### Definición del modelo
#
# **Keras** es una librería que funciona sobre **Tensorflow** y permite definir modelos de manera sencilla.
#
# **Modelo secuencial**<br>
#
# Modelo que se compone de una pila de capas, donde cada capa tiene un tensor (arreglo) de entrada y un tensor de salida. Se usa
#
# <center>
# <b>keras.Sequential()</b>
# </center>
#
# para definir un modelo secuencial
#
# La arquitectura del modelo va a contener la siguiente capa:
# <dl>
#   <dt><b>Dense</b></dt>
#   <dd>Capa de neuronas densamente conectada<br>
#      Argumentos:
#      <ul>
#       <li><b>units</b> Valor entero positivo e indica la dimensionalidad de salida
#      <li><b>activation=None</b> Función de activación, por default "linear" (a(x)=x)
#      </ul>
#   </dd>
# </dl>
#
# https://keras.io/api/layers/core_layers/dense/
#
# **Funciones de activación**<br>
#
# <dl>
#     <dt><b>relu</b></dt>
#         <dd>Si X>0 devuelve X, si no, devuelve 0</dd>
#     <dt><b>softmax</b></dt>
#         <dd>Generalmente se emplea en la última capa de una red de clasificación (más de 2 clases), debido a que el resultado se puede interpretar como una distribución de probabilidad.</dd>
#     <dt><b>sigmoid</b></dt>
#         <dd>Función de activación sigmoide, la cual retorna valores entre 0 y 1. Además, esta función es equivalente softmax de dos clases (clasificación binaria)</dd>
# </dl>
#
# https://keras.io/api/layers/activations/

# %%
# Importando librerias para definir la arquitectura
import keras
from keras.layers import Dense
from keras.models import Sequential
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-a3278fe85571> in <module>
#       1 # Importando librerias para definir la arquitectura
# ----> 2 import keras
#       3 from keras.layers import Dense
#       4 from keras.models import Sequential
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\utils\__init__.py in <module>
#      24 from .layer_utils import get_source_inputs
#      25 from .layer_utils import print_summary
# ---> 26 from .vis_utils import model_to_dot
#      27 from .vis_utils import plot_model
#      28 from .np_utils import to_categorical
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\utils\vis_utils.py in <module>
#       5
#       6 import os
# ----> 7 from ..models import Model
#       8 from ..layers.wrappers import Wrapper
#       9
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\models.py in <module>
#      10 from .engine.input_layer import Input
#      11 from .engine.input_layer import InputLayer
# ---> 12 from .engine.training import Model
#      13 from .engine.sequential import Sequential
#      14 from .engine.saving import save_model
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\engine\training.py in <module>
#      12 from .network import Network
#      13 from .base_layer import Layer
# ---> 14 from . import training_utils
#      15 from . import training_arrays
#      16 from . import training_generator
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\engine\training_utils.py in <module>
#      15 from .. import backend as K
#      16 from .. import losses
# ---> 17 from .. import metrics as metrics_module
#      18 from ..utils import Sequence
#      19 from ..utils import generic_utils
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\metrics.py in <module>
#      11
#      12 from . import backend as K
# ---> 13 from .layers import Layer
#      14 from .losses import mean_squared_error
#      15 from .losses import mean_absolute_error
#
# c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\layers\__init__.py in <module>
#       3 from ..utils.generic_utils import deserialize_keras_object
#       4 from ..engine.base_layer import Layer
# ----> 5 from ..engine import Input
#       6 from ..engine import InputLayer
#       7 from ..engine.base_layer import InputSpec
#
# ImportError: cannot import name 'Input' from 'keras.engine' (c:\Users\Denis\miniconda3\envs\entornoGPU\lib\site-packages\keras\engine\__init__.py)

# %%
# !pip install tensorflow==2.1
# !pip install keras==2.3.1
# Out:
# Requirement already satisfied: tensorflow==2.1 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (2.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (2.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (3.3.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (3.19.1)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (2.1.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.11.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.12.0)
# Requirement already satisfied: gast==0.2.2 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.21.6)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.27.2)
# Requirement already satisfied: astor>=0.6.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (0.8.1)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (2.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (0.2.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.0.8)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (1.4.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorflow==2.1) (0.33.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (41.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.4.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.28.0)
# Requirement already satisfied: h5py in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras-applications>=1.0.8->tensorflow==2.1) (2.9.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.2.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (0.4.8)
# Requirement already satisfied: more-itertools in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1) (7.2.0)
# Collecting keras==2.3.1
#   Using cached https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: pyyaml in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras==2.3.1) (5.1.2)
# Requirement already satisfied: scipy>=0.14 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: h5py in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras==2.3.1) (2.9.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras==2.3.1) (1.21.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras==2.3.1) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\denis\miniconda3\envs\entornogpu\lib\site-packages (from keras==2.3.1) (1.0.8)
# Installing collected packages: keras
#   Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
# Successfully installed keras-2.3.1

# %%
# Definición del modelo
model = Sequential()

model.add(Dense(128, activation='relu', name="Input", input_dim =13))
model.add(Dense(64, activation='relu', name="Hidden_1"))
model.add(Dense(32, activation='relu', name="Hidden_2"))
model.add(Dense(16, activation='relu', name="Hidden_3"))
model.add(Dense(1, name="Output"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (Dense)               (None, 128)               1792
#
#  Hidden_1 (Dense)            (None, 64)                8256
#
#  Hidden_2 (Dense)            (None, 32)                2080
#
#  Hidden_3 (Dense)            (None, 16)                528
#
#  Output (Dense)              (None, 1)                 17
#
# =================================================================
# Total params: 12673 (49.50 KB)
# Trainable params: 12673 (49.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# !pip install pydot
tf.keras.utils.plot_model(model, to_file="prueba.png", show_shapes=True)

# %% [markdown]
# ### Compilación del modelo
#
# <center>
# <b>model.compile</b>
# </center>
#
# Parámetros:
#
# <dl>
#     <dt><b>optimizer</b></dt>
#         <dd>Algoritmo de optimización que se utiliza para entrenar la red. El descenso del gradiente estocástico (sgd) es un ejemplo de estos algoritmos.(https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)</dd>
#     <dt><b>loss</b></dt>
#         <dd>La función de pérdida se emplea para evaluar la red durante el entrenamiento y por lo tanto su valor se minimiza, un ejemplo es mean_absolute_error (https://www.tensorflow.org/api_docs/python/tf/keras/losses)</dd>
#     <dt><b>metrics</b></dt>
#         <dd>Métricas para la evaluación (desempeño) del modelo, después de que se entreno. Por ejemplo mse (https://www.tensorflow.org/api_docs/python/tf/keras/metrics)</dd>
# </dl>

# %%
model.compile(
    optimizer = 'Adam',
    loss = 'mean_squared_error',
    metrics=['mae'] #'mse' o 'mape'
)

# %% [markdown]
# ### Entrenamiento del modelo
#
# <center>
#     <b>model.fit</b>
# </center>
#
# Entrena el modelo durante un número de épocas (iteraciones en el dataset)
#
# Parámetros
#
# *   <b>epochs</b>. Número de epocas para entrenar el modelo
# *   <b>validation_data</b>. Conjunto de datos que se emplean para evaluar la perdida al final de cada epoca.
# *   <b>batch_size</b>. Número de muestras para actualización del gradiente
# *   <b>verbose</b>. Salida del proceso de entrenamiento (0, 1, 2)

# %%
history = model.fit(
    Xtrain_norm, y_train_whole,
    epochs = 100,
    validation_data = (Xvalid_norm, y_valid),)
    #batch_size=10)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 5s 58ms/step - loss: 581.0886 - mae: 22.2812 - val_loss: 618.5198 - val_mae: 22.8424
# Epoch 2/100
# 13/13 [==============================] - 0s 13ms/step - loss: 559.7514 - mae: 21.7953 - val_loss: 567.5695 - val_mae: 21.6663
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss:
# Epoch 88/100
# 13/13 [==============================] - 0s 5ms/step - loss: 15.6341 - mae: 2.8819 - val_loss: 22.7646 - val_mae: 3.8933
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 15.4975 - mae: 2.9329 - val_loss: 28.5221 - val_mae: 4.5848
# Epoch 90/100
# 13/13 [==============================] - 0s 4ms/step - loss: 15.5765 - mae: 2.8900 - val_loss: 24.1740 - val_mae: 4.0614
# Epoch 91/100
# 13/13 [==============================] - 0s 4ms/step - loss: 15.5169 - mae: 2.8818 - val_loss: 23.8635 - val_mae: 4.0291
# Epoch 92/100
# 13/13 [==============================] - 0s 5ms/step - loss: 14.7279 - mae: 2.7933 - val_loss: 25.0777 - val_mae: 4.1523
# Epoch 93/100
# 13/13 [==============================] - 0s 6ms/step - loss: 14.4902 - mae: 2.7761 - val_loss: 24.1167 - val_mae: 4.0575
# Epoch 94/100
# 13/13 [==============================] - 0s 4ms/step - loss: 14.1950 - mae: 2.8145 - val_loss: 29.0446 - val_mae: 4.6436
# Epoch 95/100
# 13/13 [==============================] - 0s 5ms/step - loss: 14.5169 - mae: 2.8317 - val_loss: 27.5782 - val_mae: 4.4865
# Epoch 96/100
# 13/13 [==============================] - 0s 4ms/step - loss: 15.3909 - mae: 2.8801 - val_loss: 30.0330 - val_mae: 4.7260
# Epoch 97/100
# 13/13 [==============================] - 0s 5ms/step - loss: 14.9703 - mae: 2.8545 - val_loss: 23.3903 - val_mae: 4.0404
# Epoch 98/100
# 13/13 [==============================] - 0s 6ms/step - loss: 14.0364 - mae: 2.7502 - val_loss: 22.8317 - val_mae: 3.9376
# Epoch 99/100
# 13/13 [==============================] - 0s 4ms/step - loss: 14.3842 - mae: 2.8301 - val_loss: 23.5999 - val_mae: 4.0550
# Epoch 100/100
# 13/13 [==============================] - 0s 5ms/step - loss: 13.7072 - mae: 2.7615 - val_loss: 28.3579 - val_mae: 4.5694

# %%
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca()
plt.show()

# %%
train_mse=model.evaluate(X_test, y_test, verbose=0)

loss = history.history['loss']
acc = history.history['mae']
val_loss = history.history['val_loss']
val_acc = history.history['val_mae']

epochs = range(1, len(loss)+1)

plt.plot(epochs, acc, 'g*', label='Training MAE')
plt.plot(epochs, val_acc, 'y+', label='Val MAE')
plt.legend()
plt.show()

plt.plot(epochs, loss, 'r*', label='Training loss')
plt.plot(epochs, val_loss, 'b+', label='Val loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Guardar modelo
#
# <center>
#     <b>model.save</b>
# </center>
# </br>
# Guarda la arquitectura, pesos y configuración de entrenamiento del modelo. Los formatos pueden ser:
#
# <ul>
#     <li>HDF5: save_format='h5', nombre sin extensión
#     <li>SavedModel: save_format='tf', nombre con extensión h5
#     <li>Keras
# </ul>
# Mas información en: https://keras.io/api/saving/model_saving_and_loading/

# %%
model.save('number_model.h5', save_format='h5')
# model.save('number_model', save_format='tf')
# model.save('number_model.keras')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Cargar modelo

# %%
from tensorflow.keras.models import load_model
saved_model = load_model('number_model.h5')

# %% [markdown]
# ### Predicciones
#
# <center>
#     <b>model.predit</b>
# </center>
# </br>
# Retorna las predicciones del conjunto de datos de entrada.

# %%
y_pred = saved_model.predict(X_test_norm)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.27566681997800946
